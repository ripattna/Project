# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# Data Preparatin 
total = [20,4,1,30,20,10,70,30,10]
order = [10,3,1,15,17,2,30,44,2,1]
discount = [30,10,20,5,10,20,50,60,20,45]
data = list([total, order, discount])

# Plotting the data
plt.violinplot(data,showmeans = True)
plt.show()

# %% [markdown]
# # Customizing the Violin Plot

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# Data Preparatin 
total = [20,4,1,30,20,10,70,30,10]
order = [10,3,1,15,17,2,30,44,2,1]
discount = [30,10,20,5,10,20,50,60,20,45]
data = list([total, order, discount])

# Plotting the data
plt.violinplot(data, showmeans = True)
plt.title("Violin Plot Demo")
plt.grid("True")
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# Data Preparatin 
total = [20,4,1,30,20,10,70,30,10]
order = [10,3,1,15,17,2,30,44,2,1]
discount = [30,10,20,5,10,20,50,60,20,45]
data = list([total, order, discount])

# Plotting the data
plt.violinplot(data, showmeans = True, showmedians = True)
plt.title("Violin Plot Demo")
plt.grid("True")
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# Data Preparatin 
# total = [20,4,1,30,20,10,70,30,10]
# order = [10,3,1,15,17,2,30,44,2,1]
# discount = [30,10,20,5,10,20,50,60,20,45]
# data = list([total, order, discount])
boolean = [0,1,0,1,1,1,0,1,1,0]

# Plotting the data
plt.violinplot(boolean, showmeans = True, showmedians = True)
plt.title("Violin Plot Demo")
plt.grid("True")
plt.show()
