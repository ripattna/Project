# %%
import matplotlib.pyplot as plt

# Prepare the data
group_names = ['GroupA','GroupB','GroupC']
group_size = [15,30,45]
size_centre = [5]
a,b,c = [plt.cm.Blues, plt.cm.Reds, plt.cm.Greens]

# Creating the doughnut chats
pie1 = plt.pie(group_size, labels = group_names, radius = 1.5, colors = [a(0.5),b(1.5),c(1.0)])
pie2 = plt.pie(size_centre,radius = 1.0 ,colors = 'w')
plt.show()

# %%
import matplotlib.pyplot as plt

# Prepare the data
animal = ['Dog', 'Cat', 'Wolf']
sizes = [50,45,60]

# Add figure
fig =plt.figure(figsize=(10,6))
# Add axes
ax1 = plt.subplot()

a,b,c = [plt.cm.Blues, plt.cm.Reds, plt.cm.Greens]

# Creating the doughnut chats
pie1 = plt.pie(group_size, labels = animal, radius = 1.5, colors = [a(0.5),b(1.5),c(1.0)])
pie2 = plt.pie(size_centre,radius = 1.0 ,colors = 'y')
# plt.title('Daughnut Chat')
plt.show()
