# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# Prepare data
img = Image.open("puspa.png")
# Convert to .npy
arr = np.array(img)
# Add figure
fig = plt.figure(figsize=(10,5))
# Add axes
ax1 = plt.subplot()
# plot image
ax1.imshow(arr)
