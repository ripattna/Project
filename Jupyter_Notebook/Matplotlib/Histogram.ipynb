# %% [markdown]
# # Histogram

# %%
import matplotlib.pyplot as plt

# Preparing the datasets
numbers = [10,19,12,16,19,20,30,32,33,34,35,37,39,45,60,68,69,70,79,62,85,93,97]

# Creating the histogram
plt.hist(numbers, bins = [0,20,40,60,80,100])
plt.show()

# %% [markdown]
# # Customizing the Histogram

# %%
import matplotlib.pyplot as plt

# Preparing the datasets
numbers = [10,19,12,16,19,20,30,32,33,34,35,37,39,45,60,68,69,70,79,62,85,93,97]

# Creating the histogram
plt.hist(numbers, bins = [0,20,40,60,80,100], edgecolor='#000000', color ='#FF2331')
plt.title("Histogram Demo")
plt.xlabel("Range of value")
plt.ylabel("Frequence of value")
plt.grid(True)
# plt.savefig("Histogram Plot.png")
plt.show()
